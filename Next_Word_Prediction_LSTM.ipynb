# %%
import numpy as np
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
with open('/content/sherlock-holm.es_stories_plain-text_advs.txt', 'r', encoding='utf-8') as file:
    text = file.read()

print(text[:500])  # preview text
# Out:
#                         THE ADVENTURES OF SHERLOCK HOLMES
#
#                                Arthur Conan Doyle
#
#
#
#                                 Table of contents
#
#                A Scandal in Bohemia
#                The Red-Headed League
#                A Case of Identity
#                The Boscombe Valley Mystery
#                The Five Orange Pips
#                The Man with the Twisted Lip
#                The Adventure of the Blue Carbuncle
#                The Adventure of the Speckled Band

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

#Convert words into numbers (Tokenization)
tokenizer = Tokenizer()
#fit_on_texts([text]) -> Scans all words and builds vocabulary.
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1
print("Total words:", total_words)
# Out:
# Total words: 8200

# %%
input_sequences = []

for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        input_sequences.append(token_list[:i+1])

print("Total sequences:", len(input_sequences))
# Out:
# Total sequences: 96314

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

max_sequence_len = max(len(seq) for seq in input_sequences)

input_sequences = np.array(
    pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')
)

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %%
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
model.add(LSTM(150))
model.add(Dense(total_words, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.fit(X, y, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.0516 - loss: 6.7631
# Epoch 2/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.0792 - loss: 5.9734
# Epoch 3/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.1128 - loss: 5.6014
# Epoch 4/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.1319 - loss: 5.3366
# Epoch 5/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.1422 - loss: 5.1403
# Epoch 6/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.1551 - loss: 4.9586
# Epoch 7/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.1651 - loss: 4.7756
# Epoch 8/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.1771 - loss: 4.6221
# Epoch 9/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.1832 - loss: 4.4977
# Epoch 10/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.1900 - loss: 4.3732
# Epoch 11/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.1998 - loss: 4.2510
# Epoch 12/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.2084 - loss: 4.1357
# Epoch 13/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.2193 - loss: 4.0123
# Epoch 14/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.2288 - loss: 3.9055
# Epoch 15/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.2423 - loss: 3.8071
# Epoch 16/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.2581 - loss: 3.6896
# Epoch 17/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.2692 - loss: 3.6045
# Epoch 18/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.2812 - loss: 3.5128
# Epoch 19/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.2921 - loss: 3.4242
# Epoch 20/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.2998 - loss: 3.3600
# Epoch 21/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3154 - loss: 3.2667
# Epoch 22/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.3275 - loss: 3.2004
# Epoch 23/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.3393 - loss: 3.1306
# Epoch 24/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.3509 - loss: 3.0573
# Epoch 25/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.3615 - loss: 2.9929
# Epoch 26/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.3709 - loss: 2.9269
# Epoch 27/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.3839 - loss: 2.8672
# Epoch 28/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.3933 - loss: 2.8147
# Epoch 29/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.4004 - loss: 2.7680
# Epoch 30/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4132 - loss: 2.7020
# Epoch 31/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.4196 - loss: 2.6465
# Epoch 32/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.4332 - loss: 2.5941
# Epoch 33/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4415 - loss: 2.5448
# Epoch 34/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4521 - loss: 2.4891
# Epoch 35/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.4641 - loss: 2.4361
# Epoch 36/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.4673 - loss: 2.4113
# Epoch 37/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4797 - loss: 2.3534
# Epoch 38/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.4895 - loss: 2.3079
# Epoch 39/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.4973 - loss: 2.2631
# Epoch 40/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5025 - loss: 2.2360
# Epoch 41/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5155 - loss: 2.1793
# Epoch 42/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5237 - loss: 2.1391
# Epoch 43/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.5324 - loss: 2.1026
# Epoch 44/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5406 - loss: 2.0675
# Epoch 45/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5489 - loss: 2.0211
# Epoch 46/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.5535 - loss: 1.9971
# Epoch 47/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.5611 - loss: 1.9618
# Epoch 48/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.5746 - loss: 1.9121
# Epoch 49/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5772 - loss: 1.9010
# Epoch 50/50
# 753/753 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.5852 - loss: 1.8510

# %%
def predict_next_words(seed_text, next_words):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences(
            [token_list], maxlen=max_sequence_len-1, padding='pre'
        )
        predicted = np.argmax(model.predict(token_list), axis=-1)

        for word, index in tokenizer.word_index.items():
            if index == predicted:
                seed_text += " " + word
                break
    return seed_text


print(predict_next_words("I will leave if they", 3))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# I will leave if they are they in

# %%
print(predict_next_words("I love ", 9))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# I love  and am loved by the nature of the amoy

# %%
print(predict_next_words("i am ", 11))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# i am  afraid that i have not yet considerable experience of my own

# %%
history = model.fit(
    X, y,
    epochs=30,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6007 - loss: 1.7939 - val_accuracy: 0.5500 - val_loss: 1.9818
# Epoch 2/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6107 - loss: 1.7363 - val_accuracy: 0.5233 - val_loss: 2.0842
# Epoch 3/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6172 - loss: 1.7106 - val_accuracy: 0.5018 - val_loss: 2.1694
# Epoch 4/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6267 - loss: 1.6663 - val_accuracy: 0.4816 - val_loss: 2.2555
# Epoch 5/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6331 - loss: 1.6347 - val_accuracy: 0.4646 - val_loss: 2.3343
# Epoch 6/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6406 - loss: 1.6028 - val_accuracy: 0.4507 - val_loss: 2.4112
# Epoch 7/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.6486 - loss: 1.5582 - val_accuracy: 0.4288 - val_loss: 2.4926
# Epoch 8/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6565 - loss: 1.5299 - val_accuracy: 0.4161 - val_loss: 2.5781
# Epoch 9/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6639 - loss: 1.4994 - val_accuracy: 0.3994 - val_loss: 2.6593
# Epoch 10/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.6676 - loss: 1.4836 - val_accuracy: 0.3862 - val_loss: 2.7497
# Epoch 11/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6742 - loss: 1.4462 - val_accuracy: 0.3767 - val_loss: 2.8238
# Epoch 12/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.6836 - loss: 1.4060 - val_accuracy: 0.3631 - val_loss: 2.9161
# Epoch 13/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.6922 - loss: 1.3771 - val_accuracy: 0.3537 - val_loss: 2.9879
# Epoch 14/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.6962 - loss: 1.3549 - val_accuracy: 0.3411 - val_loss: 3.0749
# Epoch 15/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.7003 - loss: 1.3410 - val_accuracy: 0.3343 - val_loss: 3.1580
# Epoch 16/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.7070 - loss: 1.3018 - val_accuracy: 0.3269 - val_loss: 3.2480
# Epoch 17/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.7110 - loss: 1.2858 - val_accuracy: 0.3222 - val_loss: 3.3305
# Epoch 18/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.7182 - loss: 1.2580 - val_accuracy: 0.3163 - val_loss: 3.4192
# Epoch 19/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7176 - loss: 1.2486 - val_accuracy: 0.3104 - val_loss: 3.4986
# Epoch 20/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7248 - loss: 1.2234 - val_accuracy: 0.3081 - val_loss: 3.5709
# Epoch 21/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7293 - loss: 1.2112 - val_accuracy: 0.3019 - val_loss: 3.6494
# Epoch 22/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.7343 - loss: 1.1820 - val_accuracy: 0.2962 - val_loss: 3.7317
# Epoch 23/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7425 - loss: 1.1554 - val_accuracy: 0.2932 - val_loss: 3.8030
# Epoch 24/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7479 - loss: 1.1334 - val_accuracy: 0.2898 - val_loss: 3.8801
# Epoch 25/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7491 - loss: 1.1113 - val_accuracy: 0.2845 - val_loss: 3.9549
# Epoch 26/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7519 - loss: 1.1103 - val_accuracy: 0.2817 - val_loss: 4.0280
# Epoch 27/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7577 - loss: 1.0829 - val_accuracy: 0.2804 - val_loss: 4.0958
# Epoch 28/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7636 - loss: 1.0563 - val_accuracy: 0.2761 - val_loss: 4.1724
# Epoch 29/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7621 - loss: 1.0573 - val_accuracy: 0.2692 - val_loss: 4.2372
# Epoch 30/30
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7665 - loss: 1.0332 - val_accuracy: 0.2686 - val_loss: 4.2986

# %%
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")
# Out:
# Final Training Accuracy: 0.7591
# Final Validation Accuracy: 0.2686

# %%
import numpy as np

final_loss = history.history['loss'][-1]
perplexity = np.exp(final_loss)

print(f"Model Perplexity: {perplexity:.2f}")
# Out:
# Model Perplexity: 2.90
